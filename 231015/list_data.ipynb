# %%
import os
import pandas as pd

# %%
# csv 폴더에 있는 2018 폴더의 csv 파일들을 모두 결합하여 하나의 데이터 프레임으로 생성

# 파일의 경로를 변수에 대입
file_path = "../csv/2018/"

# 경로의 파일 리스트를 생성
file_list = os.listdir(file_path)
file_list

# 비어있는 데이터프레임 생성 - 내가 원하는 결합을 시키기 위해서 비어있는 데이터프레임을 만들고 시작
result = pd.DataFrame()

# 파일 리스트를 반복문을 이용하여 반복
for file in file_list :

    # 파일의 경로와 파일 리스트의 각원소의 값들을 결합하여 read_csv()로 데이터프레임 생성
    df = pd.read_csv(file_path + file)

    # concat()를 이용하여 비어있는 데이터 프레임과 결합
    result = pd.concat([result, df], axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/gin/Documents/GitHub/python-ezen/231015/list_data.ipynb 셀 2 line 1
#      <a href='vscode-notebook-cell:/Users/gin/Documents/GitHub/python-ezen/231015/list_data.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> # 파일 리스트를 반복문을 이용하여 반복
#      <a href='vscode-notebook-cell:/Users/gin/Documents/GitHub/python-ezen/231015/list_data.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> for file in file_list :
#      <a href='vscode-notebook-cell:/Users/gin/Documents/GitHub/python-ezen/231015/list_data.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>
#      <a href='vscode-notebook-cell:/Users/gin/Documents/GitHub/python-ezen/231015/list_data.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a>     # 파일의 경로와 파일 리스트의 각원소의 값들을 결합하여 read_csv()로 데이터프레임 생성
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42365 entries, 0 to 42364
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                42365 non-null  int64
#  1   title              42365 non-null  object
#  2   url                42365 non-null  object
#  3   dept_nm_lvl_1      42365 non-null  object
#  4   dept_nm_lvl_2      42297 non-null  object
#  5   dept_nm_lvl_3      36782 non-null  object
#  6   dept_nm_lvl_4      11473 non-null  object
#  7   dept_nm_lvl_5      1983 non-null   object
#  8   exec_yr            42365 non-null  int64
#  9   exec_month         42365 non-null  int64
#  10  expense_budget     1648 non-null   float64
#  11  expense_execution  1307 non-null   float64
#  12  category           1020 non-null   object
#  13  dept_nm_full       42365 non-null  object
#  14  exec_dt            42365 non-null  object
#  15  exec_loc           41891 non-null  object
# ...

# %%
# 특정 경로에 있는 파일 목록을 하나의 데이터프레임으로 결합하는 함수 생성
def list_load(_path, _end) :
        # _path : 파일의 경로
        # _end : 파일의 확장자

        # _path의 마지막 문자열이 '/' 가 아니라면?
        # if not(_path.endswith('/')):
        if _path[-1] !='/':
               _path = _path + '/' #<- 이것만 써도 되긴 함.
       
        # 특정 경로의 파일 리스트 생성
        file_list = os.listdir(_path)

        # 특정 확장자로 이루어진 파일 리스트를 생성
        file_list2 =[]

        for file in file_list :
               if file.endswith(_end):
                      file_list2.append(file)

        # 비어있는 데이터 프레임 생성
        result = pd.DataFrame()

        # 반복문 생성
        for file in file_list2 :
                # _end가 'csv'인 경우
                if _end == 'csv':
                    df = pd.read_csv(_path+file)
                elif _end == 'json' :
                       df = pd.read_json(_path+file)
                #elif (_end =='xls') | (_end == 'xlsx'): 이걸
                elif _end in ['xls', 'xlsx'] : # 이렇게 표현해도 된다. 더 간단하게.
                       df = pd.read_excel(_path+file)
                else:
                       return "지원하지 않는 확장자입니다."
                
                # 유니언 결합
                result = pd.concat([result, df], axis=0, ignore_index=True)

        return result

# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.8 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
list_load('../csv/2021', 'xlsx').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83819 entries, 0 to 83818
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                83819 non-null  int64
#  1   title              83819 non-null  object
#  2   url                83819 non-null  object
#  3   dept_nm_lvl_1      83819 non-null  object
#  4   dept_nm_lvl_2      83819 non-null  object
#  5   dept_nm_lvl_3      67930 non-null  object
#  6   dept_nm_lvl_4      24831 non-null  object
#  7   dept_nm_lvl_5      1473 non-null   object
#  8   exec_yr            83819 non-null  int64
#  9   exec_month         83819 non-null  int64
#  10  expense_budget     60524 non-null  float64
#  11  expense_execution  60524 non-null  float64
#  12  category           980 non-null    object
#  13  dept_nm_full       83819 non-null  object
#  14  exec_dt            83819 non-null  object
#  15  exec_loc           83185 non-null  object
# ...

# %%
file_list = os.listdir('../csv/2021/')
file_list
# Out:
# ['202110_expense_list.xlsx',
#  '202110_expense_list.xml',
#  '202105_expense_list.json',
#  '202104_expense_list.xml',
#  '202109_expense_list.xlsx',
#  '202107_expense_list.csv',
#  '202111_expense_list.xlsx',
#  '202103_expense_list.csv',
#  '202104_expense_list.json',
#  '202108_expense_list.csv',
#  '202108_expense_list.xlsx',
#  '202101_expense_list.json',
#  '202112_expense_list.xlsx',
#  '202111_expense_list.xml',
#  '202112_expense_list.csv',
#  '202107_expense_list.json',
#  '202106_expense_list.csv',
#  '202105_expense_list.xml',
#  '202102_expense_list.json',
#  '202101_expense_list.xml',
#  '202102_expense_list.csv',
#  '202106_expense_list.json',
#  '202103_expense_list.json',
#  '202109_expense_list.csv',
#  '202105_expense_list.csv',
#  '202103_expense_list.xlsx',
#  '202106_expense_list.xml',
#  '202112_expense_list.xml',
#  '202111_expense_list.csv',
#  '202106_expense_list.xlsx',
#  '202109_expense_list.xml',
#  '202102_expense_list.xlsx',
# ...

# %%
file_list2 = []

for file in file_list :
    # if 조건식(특정한 확장자를 만들 경우)
    if file.endswith('.csv'):
        file_list2.append(file)

    # 문자열에 특정한 문자가 포함되어있는가?
    # if 'csv' in file :

file_list2
# Out:
# ['202107_expense_list.csv',
#  '202103_expense_list.csv',
#  '202108_expense_list.csv',
#  '202112_expense_list.csv',
#  '202106_expense_list.csv',
#  '202102_expense_list.csv',
#  '202109_expense_list.csv',
#  '202105_expense_list.csv',
#  '202111_expense_list.csv',
#  '202101_expense_list.csv',
#  '202104_expense_list.csv',
#  '202110_expense_list.csv']

# %%
import reference.list_load as ll
import imp # 저장 전 import를 한다면 다시 불러오지 않음. 리로드 해줘야함.
# Out:
# /var/folders/9c/kgyp1x493jz2jb29m1zs2bb40000gn/T/ipykernel_4563/2026946884.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
imp.reload(ll) # 리로드
# Out:
# <module 'list_load' from '/Users/gin/Documents/GitHub/python-ezen/231015/list_load.py'>

# %%
ll.list_load('../csv/2022/', 'csv')
# Out:
#             nid                                              title  \
# 0      25741578  2022년 3월 사업소 상수도사업본부 본부 경영관리부 업무추진비 - 기관운영 시책추...
# 1      25741578  2022년 3월 사업소 상수도사업본부 본부 경영관리부 업무추진비 - 기관운영 시책추...
# 2      25741578  2022년 3월 사업소 상수도사업본부 본부 경영관리부 업무추진비 - 기관운영 시책추...
# 3      25741578  2022년 3월 사업소 상수도사업본부 본부 경영관리부 업무추진비 - 기관운영 시책추...
# 4      25741578  2022년 3월 사업소 상수도사업본부 본부 경영관리부 업무추진비 - 기관운영 시책추...
# ...         ...                                                ...
# 19349  25870795             2022년 4월 사업소 서울도서관 정보서비스과 업무추진비 - 부서운영
# 19350  25870795             2022년 4월 사업소 서울도서관 정보서비스과 업무추진비 - 부서운영
# 19351  25870795             2022년 4월 사업소 서울도서관 정보서비스과 업무추진비 - 부서운영
# 19352  25870795             2022년 4월 사업소 서울도서관 정보서비스과 업무추진비 - 부서운영
# 19353  25870795             2022년 4월 사업소 서울도서관 정보서비스과 업무추진비 - 부서운영
#
#                                                url dept_nm_lvl_1  \
# 0      http://opengov.seoul.go.kr/expense/25741578           사업소
# ...
