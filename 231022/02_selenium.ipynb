# %% [markdown]
# # Selenium 라이브러리
# 1. 웹 어플리케이션 테스트를 위한 라이브러리
# 2. python에서 웹 브라우저를 제어하기 위해 만들어진 라이브러리
# 3. (구버전)인 경우 웹 드라이버라는 별도의 소프트웨어 필요

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (4.14.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (2.0.6)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

# %%
# 새로운 웹 브라우저를 생성
driver = webdriver.Chrome()

# %%
# 웹 브라우저에 주소를 입력하여 요청을 보낸다.
driver.get("http://www.naver.com")

# %%
# html Tag의 속성 값들에 접근하기 위한 기능들을 로드
from selenium.webdriver.common.by import By
# 키보드 이벤트 리스너(enter키, backspace키, ..)에 접근하기 위한 기능 로드
from selenium.webdriver.common.keys import Keys

# %%
# 네이버의 검색창에 특정 문자열 입력

# 네이버의 검색창이 어떻게 이루어져 있는가?
# 네이버의 검색창은 id가 query로 태그가 만들어져 있다.
element = driver.find_element(By.ID, 'query')

# %%
# 검색어창에 '아이패드' 입력
element.send_keys('아이패드')

# %%
# 키보드의 엔터 이벤트 발생
element.send_keys(Keys.ENTER)

# %%
# class가 _link인 태그를 선택
element2 = driver.find_element(By.CLASS_NAME, '_link')

# %%
# 클릭 이벤트 발생
element2.click()

# %%
from bs4 import BeautifulSoup as bs

# %%
# 부모 탭의 페이지 소스 출력
driver.page_source
# Out:
# '<html lang="ko" data-useragent="mozilla/5.0 (macintosh; intel mac os x 10_15_7) applewebkit/537.36 (khtml, like gecko) chrome/118.0.0.0 safari/537.36" data-platform="macintel"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="아이패드 : 네이버 통합검색"> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'아이패드\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'아이패드\'의 네이버 통합검색 결과입니다."> <title>아이패드 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver"><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_231019a.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_231019a.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231019.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = "&abt=%5B%7B%22eid%22%3A%22SHOP-BLOCK-AD%22%2C%22vid%22%3A%229%22%7D%2C%7B%22eid%22%3A%22SBR1%22%2C%22vid%22%3A%221540%22%7D%5D"; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; var g_er_image, g_er_count = 0 ; function g_er (msg) { if (g_er_count++ > 0) return ; g_er_image = new Image() ; g_er_image.src = "http://er.search.naver.com/er?f="+g_tab+"&w="+g_stab+"&q=%EC%95%84%EC%9D%B4%ED%8C%A8%EB%93%9C&u="+encodeURIComponent(document.location)+"&m="+encodeURIComponent(msg) ; } function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\\/\\*/, \'\').replace(/\\*\\//, \'\')); } function trim_crlf (q) { var crlf = /[\\r|\\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = \'utf-8\' ; document.getElementsByTagName(\'head\')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement(\'link\') ; l.type = \'text/css\' ; l.rel = \'stylesheet\' ; if (charset) l.charset = charset ; else l.charset = \'utf-8\' ; l.media = \'screen\' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, to ...

# %%
# 웹드라이버에 모든 창을 확인
all_windows = driver.window_handles

# %%
# 자식창으로 이동
driver.switch_to.window(all_windows[1])

# %%
driver.page_source
# Out:
# '<html lang="ko"><head><meta name="viewport" content="width=device-width"><meta charset="utf-8"><title>아이패드 : 네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/img/favicon.ico"><meta property="og:title" content="아이패드 : 네이버 쇼핑"><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"><meta property="og:description" content="\'아이패드\'의 네이버쇼핑 검색 결과입니다"><meta name="next-head-count" content="7"><link rel="preconnect" href="https://static.nid.naver.com"><link rel="preconnect" href="https://lcs.naver.com"><link rel="preconnect" href="http://shopping.phinf.naver.net"><link rel="preconnect" href="https://ssl.pstatic.net"><link rel="preconnect" href="https://shopping-phinf.pstatic.net"><link rel="preconnect" href="https://volts.shopping.naver.com"><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/cc814b6780774b79.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/cc814b6780774b79.css" data-n-g=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/92b0d12586a71354.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/92b0d12586a71354.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/376c27f20f768708.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/376c27f20f768708.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/c50be88cf2fa6905.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/c50be88cf2fa6905.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/12aedf0cf6abad90.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/12aedf0cf6abad90.css" data-n-p=""><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/93b3ca22122c9120.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/93b3ca22122c9120.css"><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/ad6694c03395b564.css" as="style"><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/css/ad6694c03395b564.css"><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/1117.934363c2b7a0adbf.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/3502.d847c721c51605dc.js"></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/webpack-33c0a28ef4cd5d37.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/framework-4a0e616b56a9a4ad.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/main-7191483071d7e180.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/_next/static/chunks/pages/_app-09ba96c279374d35.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/ ...

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
div_data = soup.find("div", attrs={
    'class' : 'basicList_list_basis__uNBZx'
})

# %%
div_data
# Out:
# <div class="basicList_list_basis__uNBZx"><div><div><div class="adProduct_item__1zC9h"><div class="adProduct_inner__W_nuz"><div class="adProduct_img_area__wPZ_E"><div class="thumbnail_thumb_wrap__RbcYO _wrapper"><a class="thumbnail_thumb__Bxb6Z linkAnchor" data-i="86743046039" data-ms="1039504" data-nclick="N=a:lst*A.image,r:8,i:86743046039" href="https://adcr.naver.com/adcr?x=qqRLnpwysGGcrwV2MdMjSP///w==..." rel="noopener" target="_blank"><span class="" style="display:inline-block;width:140px;height:140px"></span></a><div class="thumbnail_btn_box____IiP"><div class="thumbnail_btn__3Gjg1"><button class="thumbnail_save__yu3R_" data-nclick="N=a:lst*A.put" type="button"><span class="thumbnail_layer_info__r_5dH">담기</span></button><div class="thumbnail_layer_info__r_5dH"><div class="thumbnail_link_box__fhsB8"><a class="thumbnail_link__i3ShY" data-nclick="N=a:lst*A.putblog" href="#">내 블로그에 담기</a><a class="thumbnail_link__i3ShY" data-nclick="N=a:lst*A.putcafe" href="#">카페에 담기</a></div></div></div></div></div></div><div class="adProduct_info_area__dTSZf"><a class="adProduct_brand_message__XaxI8 adProduct_type_red__EbCQD linkAnchor" data-i="86743046039" data-ms="1039504" data-nclick="N=a:lst*A.des,i:86743046039,r:8" href="https://adcr.naver.com/adcr?x=qqRLnpwysGGcrwV2MdMjSP///w==..." rel="noopener" target="_blank">중고 애플 전문가, 보상나라</a><div class="adProduct_title__amInq"><a class="adProduct_link__NYTV9 linkAnchor" data-i="86743046039" data-ms="1039504" data-nclick="N=a:lst*A.title,i:86743046039,r:8" href="https://adcr.naver.com/adcr?x=qqRLnpwysGGcrwV2MdMjSP///w==..." rel="noopener" target="_blank" title="[보상나라] 새상품 Apple 아이패드 에어 5세대 64G WI-FI 블루 (Black)">[보상나라] 새상품 Apple 아이패드 에어 5세대 64G WI-FI 블루 (Black)</a></div><div class="adProduct_price_area__yA7Ad"><button class="ad_ad_stk__Rfw9m" type="button">광고</button><strong class="adProduct_price__9gODs"><span class="price"><span class="price_num__S2p_v"><em>859,000</em>원</span></span><span class="price_delivery__yw_We"><svg class="price_svg_delivery__kOiSU" fill="none" height="12" width="15" xmlns="http://www.w3.org/2000/svg"><mask height="12" id="IconProductDelivery_svg__a" maskunits="userSpaceOnUse" style="mask-type:alpha" width="15" x="0" y="0"><path clip-rule="evenodd" d="M15 0H0v11.786h15V0z" fill="#fff" fill-rule="evenodd"></path></mask><g mask="url(#IconProductDelivery_svg__a)"><path clip-rule="evenodd" d="M.755 9.406c0 .021.022.044.042.044h.734c.174-.879.91-1.54 1.795-1.54.885 0 1.62.661 1.795 1.54H9.88c.174-.879.91-1.54 1.794-1.54s1.621.661 1.795 1.54h.735c.02 0 .041-.023.041-.044V6.289a2.112 2.112 0 0 0-.142-.672l-1.23-2.73c-.007-.058-.208-.192-.259-.174H9.101c-.021 0-.043.023-.043.045v4.37H.755v2.278zm2.571 1.583c.596-.001 1.078-.51 1.08-1.141-.002-.63-.484-1.14-1.08-1.14-.597 0-1.079.51-1.08 1.14.001.63.483 1.14 1.08 1.14zm8.348 0c.597-.002 1.08-.51 1.08-1.141 0-.63-.483-1.14-1.08-1.141-.596.001-1.079.51-1.08 1.141.001.63.484 1.139 1.08 1.14zM0 6.333V.84C.002.376.356.001.796 0h6.14c.44.002.795.375.796.841v.903h-.755V.841c0-.02-.022-.045-.042-.045H.795c-.019 0-.04.023-.04.045v5.492h7.55V2.758c0-.465.355-.84.796-.84h3.513c.41.017.747.243.939.626l1.23 2.73c.13.302.212.683.217 1.015v3.117c-.002.465-.355.838-.796.84h-.735c-.173.879-.91 1.539-1.795 1.539-.884 0-1.62-.66-1.795-1.54H5.121c-.174.88-.911 1.54-1.795 1.54-.885 0-1.621-.66-1.795-1.54H.797c-.441 0-.795-.374-.797-.84V6.334z" fill="#959595" fill-rule="evenodd"></path></g></svg><span class="blind">배송비</span>무료</span></strong></div><div class="adProduct_depth__s_IUT"><span class="adProduct_category__ZIAfP adProduct_nohover__zHCEV">디지털/가전</span><span class="adProduct_category__ZIAfP adProduct_nohover__zHCEV">태블릿PC</span></div><div class="adProduct_desc__uKoBP"></div><div class="adProduct_etc_box__UJJ90"><span class="adProduct_etc___brfw">등록일 <!-- -->2023.09.</span><span class="adProduct_etc___brfw"><a class="adProduct_btn_zzim__INT0S N=a:lst*A.mylist,i:86743046039,r:8" data-i="86743046039" data-nclick="N=a:lst*A.mylist,i:86743046039,r: ...

# %%
img_list = div_data.find_all('img')

# %%
img_list2 =[]

for i in img_list:
    # 태그에서 alt 속성의 값이 쿠팡이 아닌 데이터는 img_list2에 추가
    if i['alt'] != '쿠팡':
        img_list2.append(i['src'])

img_list2
# Out:
# ['https://shopping-phinf.pstatic.net/main_3590817/35908175921.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3153084/31530843620.20220705164247.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_2928180/29281800623.20211020120244.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3531799/35317993621.20221118101511.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_8344685/83446859874.2.jpg?type=f140',
#  'https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/img/search/bpower_v1.png',
#  'https://shopping-phinf.pstatic.net/main_3532017/35320178619.20221118114340.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3532382/35323829620.20221117173059.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3153181/31531810619.20220705164333.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3532286/35322861618.20221118114143.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_2928195/29281957619.20220705165729.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3123202/31232021621.20220309121253.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3531565/35315653621.20221118102057.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3153218/31532185618.20220705164537.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3532123/35321239618.20221118102237.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3153182/31531823620.20220705164511.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_2928120/29281203630.20220705170122.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_2439253/24392533524.20220705165423.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_3532453/35324537618.20221117173157.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/main_4282967/42829673152.jpg?type=f140',
#  'https://shopping-phinf.pstatic.net/20210802_10/869efbc8-4c12-45a0-8fc1-22559a603c21.jpg',
#  'https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/img/search/platinum_v1.png',
#  'https://shopping-phinf.pstatic.net/20201222_0/1409f575-f89d-4f76-9b29-e6aee9e2b5c9.jpg',
#  'https://ssl.pstatic.net/shoppingsearch/static/pc/pc-231019-161626/img/search/platinum_v1.png']
